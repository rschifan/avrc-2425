# %% [markdown]
# # Interactive Network Visualization of Game of Thrones Characters
#
# This notebook demonstrates how to create an interactive network visualization of character relationships from Game of Thrones using the book1.csv dataset.

# %% [markdown]
# ## 1. Setup and Loading Required Libraries
#
# First, let's import all the necessary libraries:

# %%
# Import libraries for data handling
import pandas as pd
import numpy as np

# Import network libraries
import networkx as nx

# Import visualization libraries
import plotly.graph_objects as go
import plotly.express as px
from plotly.offline import init_notebook_mode

# For color mapping
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# Display plots inline
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %% [markdown]
# ## 2. Loading and Processing the Network Data
#
# Let's load the Game of Thrones character network data from book1.csv. This dataset contains character interactions from the first book.

# %%
# Load the edge list from CSV
file_path = "data/got/book1.csv"
edges_df = pd.read_csv(file_path)

# Display the first few rows to understand the data structure
print(f"Dataset shape: {edges_df.shape}")
edges_df.head()
# Out:
# Dataset shape: (684, 5)
#                             Source              Target        Type  weight  \
# 0                   Addam-Marbrand     Jaime-Lannister  Undirected       3
# 1                   Addam-Marbrand     Tywin-Lannister  Undirected       6
# 2                Aegon-I-Targaryen  Daenerys-Targaryen  Undirected       5
# 3                Aegon-I-Targaryen        Eddard-Stark  Undirected       4
# 4  Aemon-Targaryen-(Maester-Aemon)      Alliser-Thorne  Undirected       4
#
#    book
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %% [markdown]
# ## 3. Creating a Network Representation with NetworkX
#
# Now we'll create a network representation using NetworkX. We'll treat characters as nodes and their interactions as edges.

# %%
# Create a graph
G = nx.Graph()

# Add edges and their weights to the graph
for _, row in edges_df.iterrows():
    source = row['Source']
    target = row['Target']
    weight = row['weight'] if 'weight' in row else 1
    
    # Add edge with weight
    G.add_edge(source, target, weight=weight)

# Print basic network statistics
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
# Out:
# Number of nodes: 187
# Number of edges: 684

# %% [markdown]
# ### 3.1 Calculate Network Metrics
#
# Let's calculate some network metrics that will help us visualize the network more effectively:
# - Degree centrality: to size the nodes
# - Community detection: to color the nodes

# %%
# Calculate degree for each node
degree = dict(G.degree())

# Detect communities using Louvain algorithm
try:
    import community as community_louvain
    communities = community_louvain.best_partition(G)
except ImportError:
    # Fallback to NetworkX's community detection
    from networkx.algorithms import community
    communities_sets = community.greedy_modularity_communities(G)
    communities = {}
    for i, comm in enumerate(communities_sets):
        for node in comm:
            communities[node] = i

# Calculate betweenness centrality for node sizing
betweenness = nx.betweenness_centrality(G)

# Create a node attribute dictionary
node_attributes = {
    node: {
        'degree': degree[node],
        'community': communities[node] if node in communities else 0,
        'betweenness': betweenness[node]
    } for node in G.nodes()
}

# Add attributes to the graph
nx.set_node_attributes(G, node_attributes)

# Define a single colormap to use throughout the notebook
num_communities = len(set(communities.values()))
# Using Plotly's qualitative color sequences for consistent coloring
network_colormap = px.colors.qualitative.D3[:num_communities]

# %%
pos = nx.spring_layout(G, k=1.00, iterations=500, seed=42)

# %% [markdown]
# ## 4. Zoom-Dependent Label Visibility
#
# To achieve truly dynamic label visibility that responds to zoom level, we need to use Plotly's FigureWidget with custom callback functions. This advanced feature allows labels to appear only when zoomed in to specific areas.

# %%
import plotly.graph_objects as go
from plotly.graph_objs import FigureWidget

def create_zoom_aware_network_widget(G, pos, zoom_threshold=0.8):
    node_x = []
    node_y = []
    node_color = []
    node_size = []
    node_text = []
    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        # Use the community ID to get color from the global colormap
        community_id = G.nodes[node]['community']
        node_color.append(network_colormap[community_id % len(network_colormap)])
        node_size.append(10 + G.nodes[node]['betweenness'] * 100)
        node_text.append(node)

    # Get edge weights to calculate min and max for scaling
    edge_weights = [data.get('weight', 1) for _, _, data in G.edges(data=True)]
    min_weight = min(edge_weights) if edge_weights else 1
    max_weight = max(edge_weights) if edge_weights else 1
    
    # Define min and max edge width for better aesthetics
    min_edge_width = 0.5
    max_edge_width = 4.0
    
    # Prepare edge data (edges first, so nodes are on top)
    edge_traces = []
    for source, target, data in G.edges(data=True):
        x0, y0 = pos[source]
        x1, y1 = pos[target]
        weight = data.get('weight', 1)
        
        # Scale edge width between min and max width based on weight
        if max_weight > min_weight:  # Avoid division by zero
            normalized_weight = (weight - min_weight) / (max_weight - min_weight)
            width = min_edge_width + normalized_weight * (max_edge_width - min_edge_width)
        else:
            width = min_edge_width
            
        edge_traces.append(go.Scatter(
            x=[x0, x1, None],
            y=[y0, y1, None],
            line=dict(width=width, color='rgba(150,150,150,0.75)'),
            hoverinfo='none',
            mode='lines'
        ))

    # Node trace with labels initially hidden
    node_trace = go.Scatter(
        x=node_x,
        y=node_y,
        mode='markers+text',
        marker=dict(
            size=node_size,
            color=node_color,
            line=dict(width=1, color='rgba(50,50,50,0.8)'),
            opacity=1  # Setting node opacity to fully opaque
        ),
        text=node_text,
        textposition='top center',
        textfont=dict(size=10, color='black'),
        hoverinfo='text',
        showlegend=False,
        visible=True
    )
    node_trace.textfont.color = 'rgba(0,0,0,0)'

    fig = FigureWidget(data=edge_traces + [node_trace])
    fig.update_layout(
        title='Game of Thrones Character Network with Zoom-Dependent Labels',
        showlegend=False,
        hovermode='closest',
        margin=dict(b=20, l=5, r=5, t=40),
        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        width=1200,
        height=800,
        paper_bgcolor='white',
        plot_bgcolor='white'
    )


    # Parameters for font size adjustment - now tied to zoom_threshold
    min_font_size = 8
    max_font_size = 14
    min_zoom_span = zoom_threshold * 0.25  # Very zoomed in (25% of threshold)
    max_zoom_span = zoom_threshold * 2.5   # Not zoomed in much (250% of threshold)
    
    def update_labels(trace, points, state):
        x_range = fig.layout.xaxis.range
        y_range = fig.layout.yaxis.range
        if x_range and y_range:
            x_span = abs(x_range[1] - x_range[0])
            y_span = abs(y_range[1] - y_range[0])
            
            # Use the average of x and y span as our zoom measure
            zoom_span = (x_span + y_span) / 2
            
            if zoom_span < zoom_threshold:
                # Calculate dynamic font size based on zoom level
                if zoom_span <= min_zoom_span:
                    # Maximum font size when very zoomed in
                    font_size = max_font_size
                elif zoom_span >= max_zoom_span:
                    # Minimum font size when zoomed out
                    font_size = min_font_size
                else:
                    # Linear scaling between min and max font size
                    zoom_ratio = (zoom_span - min_zoom_span) / (max_zoom_span - min_zoom_span)
                    font_size = max_font_size - zoom_ratio * (max_font_size - min_font_size)
                
                fig.data[-1].textfont.color = 'black'
                fig.data[-1].textfont.size = font_size
            else:
                # Hide labels when zoomed out too far
                fig.data[-1].textfont.color = 'rgba(0,0,0,0)'

    fig.layout.on_change(update_labels, 'xaxis', 'yaxis')

    return fig

# Example usage:
zoom_aware_fig_widget = create_zoom_aware_network_widget(G, pos, zoom_threshold=0.8)
zoom_aware_fig_widget
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'a25cbc7c-d414-487a-a8fa-a79ea03cbabd',
#               'x': [0.22497279778933718, 0.010251626732481109, None],
#               'y': [-0.08496436427478211, -0.04380961742058167, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5364583333333334},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '428540b6-1157-4692-bdd2-8a3fcf81c230',
#               'x': [0.22497279778933718, 0.037115510346755934, None],
#               'y': [-0.08496436427478211, -0.04556504226486564, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '72582cb2-51da-436b-b535-7f80d369ed74',
#               'x': [0.010251626732481109, 0.08491083176869271, None],
#               'y': [-0.04380961742058167, 0.12473561619199211, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '8718a04e-f9a1-4d9f-89da-0851a6c67502',
#               'x': [0.010251626732481109, -0.028591419924496733, None],
#               'y': [-0.04380961742058167, 0.07612655697441971, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5486111111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'fa8bb5bc-7848-4e68-acff-1f8bfd5244b8',
#               'x': [0.010251626732481109, 0.10938868820537545, None],
#               'y': [-0.04380961742058167, -0.06118531894569941, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5729166666666666},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '9cfde7a9-8e98-4f11-b642-5a486ad71274',
#               'x': [0.010251626732481109, 0.06194025163852019, None],
#               'y': [-0.04380961742058167, -0.06618915395174273, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6579861111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'c36c8b56-538a-4541-ac73-b26999a32dd4',
#               'x': [0.010251626732481109, -0.022186201743025914, None],
#               'y': [-0.04380961742058167, -0.01750205930681156, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.7916666666666666},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '6797011e-b8cf-4c23-89ed-278353d389f2',
#               'x': [0.010251626732481109, -0.02871746503154129, None],
#               'y': [-0.04380961742058167, 0.036267055185552, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '3b61578a-a759-4e28-bfc6-bda6681991aa',
#               'x': [0.010251626732481109, 0.19935865106779074, None],
#               'y': [-0.04380961742058167, -0.038527514911401585, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '735dc21a-4806-40cc-ad48-5f0cb875a6ec',
#               'x': [0.010251626732481109, -0.2039365687455249, None],
#               'y': [-0.04380961742058167, -0.04421651183456801, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '1c24b7ef-ee64-417a-a349-149323a0f001',
#               'x': [0.010251626732481109, 0.07294869903960982, None],
#               'y': [-0.04380961742058167, 0.034753168571194, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '38cc6968-a72a-4771-9768-a5d7c5b2dffe',
#               'x': [0.010251626732481109, 0.03688215153534709, None],
#               'y': [-0.04380961742058167, -0.41647305879552193, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.609375},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'c68591f2-6eee-4700-bc67-a63c124cd378',
#               'x': [0.010251626732481109, -0.046287056086820724, None],
#               'y': [-0.04380961742058167, -0.014601758390320642, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '0a381a8c-36c4-4400-a4c6-1e5b0d6ce945',
#               'x': [0.010251626732481109, 0.028560286713746337, None],
#               'y': [-0.04380961742058167, 0.019328167884220482, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '5019a39f-a41b-4040-993f-c81dc5ee5e51',
#               'x': [0.010251626732481109, -0.11862803199269364, None],
#               'y': [-0.04380961742058167, 0.016043508926059612, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'b2f403ab-e5ee-476b-91d1-c84acefbf180',
#               'x': [0.010251626732481109, 0.11494648298169821, None],
#               'y': [-0.04380961742058167, -0.14338730497725938, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '47a5588b-b4af-4e5f-98dd-cd60e9320931',
#               'x': [0.010251626732481109, -0.04665127655024265, None],
#               'y': [-0.04380961742058167, 0.12442501654906041, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5364583333333334},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'e9286d1e-2483-4177-874d-14deb7a94522',
#               'x': [0.010251626732481109, 0.11330801445811606, None],
#               'y': [-0.04380961742058167, -0.08228838589389197, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5486111111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '4f5c826e-8c36-4791-938c-e57c40ccf6d4',
#               'x': [0.010251626732481109, 0.0024492935087870346, None],
#               'y': [-0.04380961742058167, 0.011523455013212168, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'dd42a32c-3a47-4f2b-9c77-3e34a1d73ae0',
#               'x': [0.010251626732481109, -0.023622714361501932, None],
#               'y': [-0.04380961742058167, 0.05676646183254871, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '466d53b7-05b0-45a0-95b8-f49ce34ab18c',
#               'x': [0.010251626732481109, -0.14750468137416475, None],
#               'y': [-0.04380961742058167, -0.08086804850954817, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5729166666666666},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '0703f04e-0b6f-4bbd-bc03-a17cdeb993b1',
#               'x': [0.010251626732481109, -0.05074738356646757, None],
#               'y': [-0.04380961742058167, -0.08496490340979346, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.7552083333333334},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '86861df9-b950-488d-8a92-7d284bc8d6d6',
#               'x': [0.010251626732481109, 0.0036048677372238006, None],
#               'y': [-0.04380961742058167, 0.06583534728940707, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '46381ccf-7380-49e8-86bf-3326fb5f7c61',
#               'x': [0.010251626732481109, 0.003963020355184024, None],
#               'y': [-0.04380961742058167, -0.09203232574546034, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.609375},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '6b51e6c8-e370-4b0e-be87-6e1d39b47d5c',
#               'x': [0.010251626732481109, -0.048134864099364884, None],
#               'y': [-0.04380961742058167, 0.032972193429283654, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '32b459cc-7a28-4ec5-86be-d725a35bb898',
#               'x': [0.010251626732481109, -0.05326118188860863, None],
#               'y': [-0.04380961742058167, 0.00081962783918899, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.9010416666666666},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'baa26897-e6a6-4f6c-94f9-3a5c5cef223d',
#               'x': [0.010251626732481109, 0.031517490150687125, None],
#               'y': [-0.04380961742058167, -0.16127417515269063, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6579861111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '1d420ddf-2ad0-4c10-8f49-af90e095cc37',
#               'x': [0.010251626732481109, 0.037115510346755934, None],
#               'y': [-0.04380961742058167, -0.04556504226486564, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '9248119d-6714-4eb2-9f25-f9eae5835a5b',
#               'x': [0.010251626732481109, 0.02389194180820817, None],
#               'y': [-0.04380961742058167, 0.07424730451617607, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '2c60fabc-2c6b-49b3-87da-795af6c4c00f',
#               'x': [0.010251626732481109, -0.2570983275390851, None],
#               'y': [-0.04380961742058167, 0.057540878323252435, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'cb7415c7-6f3a-4cb9-bbc3-e09b9d8c928a',
#               'x': [0.037115510346755934, 0.09712234377324344, None],
#               'y': [-0.04556504226486564, -0.20358152371829957, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '21483aa1-9323-4d08-b9b2-320904d4bb65',
#               'x': [0.037115510346755934, 0.10938868820537545, None],
#               'y': [-0.04556504226486564, -0.06118531894569941, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5486111111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'f7280f08-df0b-4ca2-b588-1a903ff7b70c',
#               'x': [0.037115510346755934, 0.06194025163852019, None],
#               'y': [-0.04556504226486564, -0.06618915395174273, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5850694444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '04088725-84f3-4561-9b57-f571484596a1',
#               'x': [0.037115510346755934, -0.022186201743025914, None],
#               'y': [-0.04556504226486564, -0.01750205930681156, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6822916666666667},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'ab68bfff-b677-46db-9387-c789ea244a33',
#               'x': [0.037115510346755934, -0.02871746503154129, None],
#               'y': [-0.04556504226486564, 0.036267055185552, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5364583333333334},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '2298d96b-3cf3-4a61-a2d8-ffd41402e2ac',
#               'x': [0.037115510346755934, 0.07294869903960982, None],
#               'y': [-0.04556504226486564, 0.034753168571194, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'fd668418-78c0-4a2e-8331-ea7c7f470b09',
#               'x': [0.037115510346755934, -0.046287056086820724, None],
#               'y': [-0.04556504226486564, -0.014601758390320642, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '5c6c070b-ab59-48bd-9e78-5c6282f2f321',
#               'x': [0.037115510346755934, -0.17891586497063866, None],
#               'y': [-0.04556504226486564, -0.10020259579276997, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5729166666666666},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '877f2895-ab8c-42f3-a813-fc5498ee28ab',
#               'x': [0.037115510346755934, 0.11494648298169821, None],
#               'y': [-0.04556504226486564, -0.14338730497725938, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '3e1eccbe-77fc-43cd-9535-b17da63761aa',
#               'x': [0.037115510346755934, 0.25688721168021583, None],
#               'y': [-0.04556504226486564, 0.03791085183035738, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'c6aac049-ccf3-4216-a3eb-c68b0602237c',
#               'x': [0.037115510346755934, 0.02235291468424554, None],
#               'y': [-0.04556504226486564, 0.05085117760306701, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '042ac8a0-5b75-45ad-ba79-b30636168e10',
#               'x': [0.037115510346755934, 0.05033721076570676, None],
#               'y': [-0.04556504226486564, 0.19907184741777034, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5729166666666666},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '5a8a9d7b-bc86-4f3b-b2c4-0320ce92b09d',
#               'x': [0.037115510346755934, -0.05074738356646757, None],
#               'y': [-0.04556504226486564, -0.08496490340979346, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6215277777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '66fb6d2e-d3b8-435f-b269-f8ff9c4634c1',
#               'x': [0.037115510346755934, 0.0036048677372238006, None],
#               'y': [-0.04556504226486564, 0.06583534728940707, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '44079c67-a411-416f-821c-9e8092659725',
#               'x': [0.037115510346755934, -0.2208842995371462, None],
#               'y': [-0.04556504226486564, -0.10033966795492102, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '46620473-e88f-45c1-8a07-94aa2bd83d47',
#               'x': [0.037115510346755934, 0.040720318249053714, None],
#               'y': [-0.04556504226486564, 0.03787620726927046, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '6edaf042-4bae-46f6-9712-cb253cab5912',
#               'x': [0.037115510346755934, -0.03102323581745188, None],
#               'y': [-0.04556504226486564, -0.10105305642713791, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.9496527777777777},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '7b734b1c-0f4d-4f49-ac8f-ba36a4c7ae34',
#               'x': [0.037115510346755934, 0.031517490150687125, None],
#               'y': [-0.04556504226486564, -0.16127417515269063, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '4c39cd52-f7ee-482e-88d6-056d4772ec91',
#               'x': [0.037115510346755934, 0.02389194180820817, None],
#               'y': [-0.04556504226486564, 0.07424730451617607, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5607638888888888},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'da97082f-357e-4be0-bb63-1196822b9d88',
#               'x': [0.037115510346755934, 0.019376110765845708, None],
#               'y': [-0.04556504226486564, 0.11311563170645042, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '5b40449d-aea6-48d9-a477-f72e9f993a78',
#               'x': [0.044991135473526234, 0.12742448449317192, None],
#               'y': [0.34346518565637896, 0.44264659066810486, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '30edd6fc-a926-405e-ab26-af2aaa983544',
#               'x': [0.044991135473526234, -0.02871746503154129, None],
#               'y': [0.34346518565637896, 0.036267055185552, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5972222222222222},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'b7bd227a-61e5-4dc5-ad77-46340c324e96',
#               'x': [0.12742448449317192, 0.1616998707866877, None],
#               'y': [0.44264659066810486, 0.6005064938486256, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5486111111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'dec617fc-6d34-4d7d-95bc-22d8ded87f53',
#               'x': [0.12742448449317192, 0.24629594239151978, None],
#               'y': [0.44264659066810486, 0.5949285473098034, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6458333333333333},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '46ec5747-f9da-4cf8-b232-6e888d695d6a',
#               'x': [0.12742448449317192, 0.09412768350992229, None],
#               'y': [0.44264659066810486, 0.5583376061540684, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 1.6909722222222223},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '681934eb-dc99-42cc-86a0-30313b32acb7',
#               'x': [0.12742448449317192, 0.1608139389089895, None],
#               'y': [0.44264659066810486, 0.5132799100665119, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'e650ad66-7e24-4485-b848-574652ed03e5',
#               'x': [0.12742448449317192, -0.02871746503154129, None],
#               'y': [0.44264659066810486, 0.036267055185552, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '961451a8-daad-4b45-be19-ea15906160e2',
#               'x': [0.12742448449317192, 0.11715293817266567, None],
#               'y': [0.44264659066810486, 0.7186884483331629, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.609375},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'bd3e2c5c-da49-47fa-9227-c1e5a763bbb9',
#               'x': [0.12742448449317192, 0.21726183282470504, None],
#               'y': [0.44264659066810486, 0.5769598159430281, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.7552083333333334},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '59157b9e-be61-48d6-9dfa-7be99ba8a147',
#               'x': [0.12742448449317192, 0.12634131567576753, None],
#               'y': [0.44264659066810486, 0.3856023877157474, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.7673611111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '9b2aa09b-165b-4cc9-9c1c-5a7ec8bc9fea',
#               'x': [0.12742448449317192, 0.11855241411821493, None],
#               'y': [0.44264659066810486, 0.517464941498897, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.7795138888888888},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'e7c384d2-22e3-4ac5-9b8d-f13be740d1ad',
#               'x': [0.12742448449317192, 0.12136151630638026, None],
#               'y': [0.44264659066810486, 0.5473969147316472, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6701388888888888},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '98b7a7bc-26ec-4868-8b54-4e6afa16c2ea',
#               'x': [0.12742448449317192, 0.15069620326913044, None],
#               'y': [0.44264659066810486, 0.5627851226084801, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 1.375},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '44572426-fae4-47b6-ba23-f14087eb0eb6',
#               'x': [0.12742448449317192, 0.11343232239299353, None],
#               'y': [0.44264659066810486, 0.44386355044543274, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.8402777777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'd4464070-e8f2-4d73-a076-b5857854fabf',
#               'x': [0.12742448449317192, 0.19347099638183396, None],
#               'y': [0.44264659066810486, 0.5110471029680168, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6822916666666667},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '83c9614f-c808-4f36-942e-f1931382b498',
#               'x': [0.12742448449317192, 0.19077616048481424, None],
#               'y': [0.44264659066810486, 0.549854725979277, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'd3a24514-d3a3-41c8-8d0c-c7ec879f515d',
#               'x': [0.12742448449317192, 0.17989002597056203, None],
#               'y': [0.44264659066810486, 0.6645412717305139, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'b8a717d7-f011-4d3d-aa4c-5d77d473fa67',
#               'x': [0.12742448449317192, 0.2218092418629976, None],
#               'y': [0.44264659066810486, 0.6614246042222187, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'd7b0e3d1-8d94-4191-9192-ad8d2322a7a0',
#               'x': [0.12742448449317192, 0.05033721076570676, None],
#               'y': [0.44264659066810486, 0.19907184741777034, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5972222222222222},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '0898d53e-e55c-4444-a8c1-2bcaa0405505',
#               'x': [0.12742448449317192, 0.0036048677372238006, None],
#               'y': [0.44264659066810486, 0.06583534728940707, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '2a038cb8-b70b-4c5f-8148-72e91035c7a5',
#               'x': [0.12742448449317192, 0.02389194180820817, None],
#               'y': [0.44264659066810486, 0.07424730451617607, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.9131944444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '648d361a-7ebe-4450-b71b-5b791ad879b8',
#               'x': [0.12742448449317192, 0.10131094915199187, None],
#               'y': [0.44264659066810486, 0.3875788216699216, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5850694444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '00e99d87-e080-4f2b-bd4a-a1c8ab98c249',
#               'x': [-0.02871746503154129, 0.08491083176869271, None],
#               'y': [0.036267055185552, 0.12473561619199211, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5972222222222222},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'edc109ba-e294-4dea-933f-c555ce99ca41',
#               'x': [-0.02871746503154129, -0.15656006930816044, None],
#               'y': [0.036267055185552, 0.13213256207037227, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.828125},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '91746417-d052-4657-9b05-fc32a5dbd2c7',
#               'x': [-0.02871746503154129, -0.09209666469664772, None],
#               'y': [0.036267055185552, -0.03435648026563328, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '6904799c-f3ac-4c0e-829f-f2be44f337d5',
#               'x': [-0.02871746503154129, -0.01537939526896181, None],
#               'y': [0.036267055185552, 0.28442934444591567, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.8038194444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'ed58bf9a-96a9-4143-a83c-619e55794332',
#               'x': [-0.02871746503154129, -0.028591419924496733, None],
#               'y': [0.036267055185552, 0.07612655697441971, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '70f633b5-1d8a-4090-bb6b-959625dd0267',
#               'x': [-0.02871746503154129, 0.13095309585043252, None],
#               'y': [0.036267055185552, 0.17039425847655115, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6944444444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '51fa9356-c8a6-4170-aa2a-d86cc10f041f',
#               'x': [-0.02871746503154129, -0.09060749307545934, None],
#               'y': [0.036267055185552, -0.09795467628320692, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5972222222222222},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'a90a77e2-000c-4b48-8834-cb8c3b905cdd',
#               'x': [-0.02871746503154129, -0.06601520955026732, None],
#               'y': [0.036267055185552, 0.13618269573462585, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 1.2413194444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '84507592-08b1-447f-9499-11bba10ad8f4',
#               'x': [-0.02871746503154129, 0.06194025163852019, None],
#               'y': [0.036267055185552, -0.06618915395174273, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5486111111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '620a6710-ec3b-44ba-8bb7-125f53a552c6',
#               'x': [-0.02871746503154129, -0.1121886729370629, None],
#               'y': [0.036267055185552, 0.21239984013450902, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 1.3020833333333333},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '2ccdc742-3241-4c23-951b-bc71c368bebd',
#               'x': [-0.02871746503154129, -0.022186201743025914, None],
#               'y': [0.036267055185552, -0.01750205930681156, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'ed49fbf9-ca00-4e72-869d-7e614266f87e',
#               'x': [-0.02871746503154129, -0.2688654504382972, None],
#               'y': [0.036267055185552, 0.31497845469404867, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'cf2483cd-8b8c-489e-b49e-e01624df9ec6',
#               'x': [-0.02871746503154129, -0.3149465432067531, None],
#               'y': [0.036267055185552, 0.03544766942456946, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '0b6a68bd-4373-497f-a14b-1708d3cffd63',
#               'x': [-0.02871746503154129, 0.19935865106779074, None],
#               'y': [0.036267055185552, -0.038527514911401585, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '7af63742-88c8-4103-99d0-77909a5ac23e',
#               'x': [-0.02871746503154129, -0.2039365687455249, None],
#               'y': [0.036267055185552, -0.04421651183456801, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '98b17f4c-2c15-4f3e-a979-87fae969ffe7',
#               'x': [-0.02871746503154129, -0.38169262618710575, None],
#               'y': [0.036267055185552, 0.21309686890284602, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '58f608a0-7cd9-4e00-94e2-724a210fdc25',
#               'x': [-0.02871746503154129, 0.2990856928992369, None],
#               'y': [0.036267055185552, 0.23014075098947423, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5850694444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '3ff4d822-0822-49bc-8369-e47dce10f25b',
#               'x': [-0.02871746503154129, 0.07294869903960982, None],
#               'y': [0.036267055185552, 0.034753168571194, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '2abefd22-9920-4fa9-99e2-de1c02d33f1b',
#               'x': [-0.02871746503154129, -0.25463187827609834, None],
#               'y': [0.036267055185552, 0.11104111562652616, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'f2c13e69-b79d-45db-883a-a2b73d14aa7c',
#               'x': [-0.02871746503154129, -0.23374513182804255, None],
#               'y': [0.036267055185552, 0.15384839726899394, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '1cc939aa-da43-45a2-a2bd-5626dd684cc9',
#               'x': [-0.02871746503154129, 0.22558063616922255, None],
#               'y': [0.036267055185552, 0.2756448527590119, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5364583333333334},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'f43d8f87-3cce-48a8-b89c-33f2323652ca',
#               'x': [-0.02871746503154129, -0.0755085641596945, None],
#               'y': [0.036267055185552, 0.0882885776627483, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '6838363b-e064-4c65-87ee-461cba5b9ff8',
#               'x': [-0.02871746503154129, -0.23199383687950093, None],
#               'y': [0.036267055185552, 0.2902236543996118, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '5afb82c2-548b-4421-b2a1-edfcedeb8f82',
#               'x': [-0.02871746503154129, 0.09069044876566394, None],
#               'y': [0.036267055185552, 0.08036713940899422, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.7795138888888888},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '77da1754-3ba6-406a-818f-573398365d23',
#               'x': [-0.02871746503154129, -0.046287056086820724, None],
#               'y': [0.036267055185552, -0.014601758390320642, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 1.0347222222222223},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '5ac16bf9-1ce5-46c5-8350-1c160a36aee4',
#               'x': [-0.02871746503154129, 0.028560286713746337, None],
#               'y': [0.036267055185552, 0.019328167884220482, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.9253472222222222},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'dc7f0df6-057f-42e3-8d38-53fe625ee793',
#               'x': [-0.02871746503154129, -0.12443486389470393, None],
#               'y': [0.036267055185552, -0.17729694503380924, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.8524305555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'a165aeb1-dd93-49bd-b6c8-e113335ef37e',
#               'x': [-0.02871746503154129, -0.11862803199269364, None],
#               'y': [0.036267055185552, 0.016043508926059612, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '7bbe5439-27fb-4c1e-ab25-6c290702f484',
#               'x': [-0.02871746503154129, 0.23956778163397352, None],
#               'y': [0.036267055185552, 0.1484149538256008, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.609375},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '605eb0fc-0728-4dae-9efe-a7caa6abd1bf',
#               'x': [-0.02871746503154129, -0.04665127655024265, None],
#               'y': [0.036267055185552, 0.12442501654906041, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6579861111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '25616645-cfc4-4e39-a55b-814571b3c63a',
#               'x': [-0.02871746503154129, -0.08805631732446988, None],
#               'y': [0.036267055185552, -0.11784774625240702, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6944444444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '67a8e294-1428-4a36-9065-764755c97470',
#               'x': [-0.02871746503154129, -0.0106468936089344, None],
#               'y': [0.036267055185552, 0.15352205106340697, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.609375},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '679803c7-52aa-4353-9a0d-71a0ddcb819c',
#               'x': [-0.02871746503154129, 0.11330801445811606, None],
#               'y': [0.036267055185552, -0.08228838589389197, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '6b9ee1db-4fbc-45a3-bc51-baae6d6f8918',
#               'x': [-0.02871746503154129, 0.25688721168021583, None],
#               'y': [0.036267055185552, 0.03791085183035738, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5972222222222222},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '806461d2-cda4-4057-bb5a-cd135a4c082c',
#               'x': [-0.02871746503154129, -0.09163438515407198, None],
#               'y': [0.036267055185552, -0.004053042826987958, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'e434bf8e-eb69-4360-b066-b8b56e819edb',
#               'x': [-0.02871746503154129, -0.1462622574933882, None],
#               'y': [0.036267055185552, 0.006970186251841997, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 1.4479166666666665},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '79a4f62c-d48a-4622-bc08-f2bb7f70a6e2',
#               'x': [-0.02871746503154129, 0.0024492935087870346, None],
#               'y': [0.036267055185552, 0.011523455013212168, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '8ede8a85-a571-435e-b6eb-4fcb04c9c5c6',
#               'x': [-0.02871746503154129, -0.2949851579486325, None],
#               'y': [0.036267055185552, 0.2355759063004008, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.8645833333333334},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '89af656b-901a-4c9e-baff-9356a2192230',
#               'x': [-0.02871746503154129, 0.02235291468424554, None],
#               'y': [0.036267055185552, 0.05085117760306701, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '1783123e-dd28-4dc5-b8ff-ec01333d7c02',
#               'x': [-0.02871746503154129, 0.04353500827132854, None],
#               'y': [0.036267055185552, 0.232779520069315, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.8645833333333334},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '85d1f486-61bd-4235-96f2-75dd778dd499',
#               'x': [-0.02871746503154129, -0.023622714361501932, None],
#               'y': [0.036267055185552, 0.05676646183254871, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5850694444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'c1a5960f-8030-4f23-b054-f93a462ad2f3',
#               'x': [-0.02871746503154129, 0.05033721076570676, None],
#               'y': [0.036267055185552, 0.19907184741777034, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '6dc672ee-2592-4200-9cea-808fb34d673f',
#               'x': [-0.02871746503154129, -0.14750468137416475, None],
#               'y': [0.036267055185552, -0.08086804850954817, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5121527777777778},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'a980fae5-8f1e-4f75-8cfd-6a02aea5c231',
#               'x': [-0.02871746503154129, -0.06370465548097369, None],
#               'y': [0.036267055185552, -0.12730109514013377, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6579861111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '4b8c7651-92e9-4b53-a963-605fe430db44',
#               'x': [-0.02871746503154129, -0.05074738356646757, None],
#               'y': [0.036267055185552, -0.08496490340979346, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 4.0},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '84714030-daeb-4311-b30f-7b0928e5dc9a',
#               'x': [-0.02871746503154129, 0.0036048677372238006, None],
#               'y': [0.036267055185552, 0.06583534728940707, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5486111111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'b2306346-d36e-4f85-936d-fa2b04b77db3',
#               'x': [-0.02871746503154129, 0.003963020355184024, None],
#               'y': [0.036267055185552, -0.09203232574546034, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5850694444444444},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'cf31f735-d9fb-496f-81b8-05e464c59024',
#               'x': [-0.02871746503154129, -0.048134864099364884, None],
#               'y': [0.036267055185552, 0.032972193429283654, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.8767361111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '7c77f9bc-acf8-483e-ac8f-4fa0da42da00',
#               'x': [-0.02871746503154129, -0.05326118188860863, None],
#               'y': [0.036267055185552, 0.00081962783918899, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.6822916666666667},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '8940a905-5db9-414c-b784-77b4c053ffcd',
#               'x': [-0.02871746503154129, 0.040720318249053714, None],
#               'y': [0.036267055185552, 0.03787620726927046, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5364583333333334},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '254bc2e8-1832-49ce-822e-8e980afc9970',
#               'x': [-0.02871746503154129, -0.19857399538804427, None],
#               'y': [0.036267055185552, 0.0201330310551726, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5243055555555556},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': 'd05d76f0-8bed-4ec8-a0fe-078cf638ff5d',
#               'x': [-0.02871746503154129, -0.03102323581745188, None],
#               'y': [0.036267055185552, -0.10105305642713791, None]},
#              {'hoverinfo': 'none',
#               'line': {'color': 'rgba(150,150,150,0.75)', 'width': 0.5486111111111112},
#               'mode': 'lines',
#               'type': 'scatter',
#               'uid': '1a4238c4-2c41-4ac8-b407-0838c6d0f130',
# ...
#                                   10.009590235396686, 10.0, 10.00484355323065,
#                                   10.282048219206828, 10.285750369148584,
#                                   12.138913106655043, 10.0, 10.0, 10.0, 10.0,
#                                   10.02722999497193, 10.0, 10.0, 10.0,
#                                   11.0752688172043, 10.0, 10.0, 10.087066934874423,
#                                   10.0, 10.0, 10.0, 10.0, 10.0, 10.62369436762998,
#                                   10.0, 10.0, 10.0, 10.0, 10.0, 10.16301901690896,
#                                   10.0, 10.0, 10.002494429913785,
#                                   10.432821261368977, 10.0, 10.0, 10.0, 10.0, 10.0,
#                                   10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0,
#                                   10.0, 10.0, 10.0, 10.0, 10.0, 10.0,
#                                   11.0752688172043, 10.0, 10.0, 10.0, 10.0, 10.0,
#                                   10.0, 10.0]},
#               'mode': 'markers+text',
#               'showlegend': False,
#               'text': [Addam-Marbrand, Jaime-Lannister, Tywin-Lannister, Aegon-I-
#                        Targaryen, Daenerys-Targaryen, Eddard-Stark, Aemon-
#                        Targaryen-(Maester-Aemon), Alliser-Thorne, Bowen-Marsh,
#                        Chett, Clydas, Jeor-Mormont, Jon-Snow, Samwell-Tarly, Aerys-
#                        II-Targaryen, Brandon-Stark, Gerold-Hightower, Jon-Arryn,
#                        Robert-Baratheon, Aggo, Drogo, Jhogo, Jorah-Mormont, Quaro,
#                        Rakharo, Albett, Halder, Rast, Grenn, Pypar, Tyrion-
#                        Lannister, Alyn, Harwin, Jory-Cassel, Tomard, Arthur-Dayne,
#                        Arya-Stark, Benjen-Stark, Bran-Stark, Catelyn-Stark, Cersei-
#                        Lannister, Desmond, Ilyn-Payne, Jeyne-Poole, Joffrey-
#                        Baratheon, Meryn-Trant, Mordane, Mycah, Myrcella-Baratheon,
#                        Petyr-Baelish, Rickon-Stark, Robb-Stark, Rodrik-Cassel,
#                        Sandor-Clegane, Sansa-Stark, Syrio-Forel, Tommen-Baratheon,
#                        Vayon-Poole, Yoren, Arys-Oakheart, Balon-Greyjoy, Balon-
#                        Swann, Renly-Baratheon, Barristan-Selmy, Boros-Blount,
#                        Pycelle, Varys, Jaremy-Rykker, Luwin, Mance-Rayder, Theon-
#                        Greyjoy, Waymar-Royce, Beric-Dondarrion, Gregor-Clegane,
#                        Loras-Tyrell, Thoros-of-Myr, Hali, Hallis-Mollen, Hodor,
#                        Hullen, Joseth, Nan, Osha, Rickard-Karstark, Rickard-Stark,
#                        Stiv, Lyanna-Stark, Bronn, Chiggen, Marillion, Shae, Shagga,
#                        Vardis-Egen, Willis-Wode, Brynden-Tully, Edmure-Tully,
#                        Hoster-Tully, Lysa-Arryn, Nestor-Royce, Walder-Frey,
#                        Colemon, Donnel-Waynwood, Eon-Hunter, Jon-Umber-(Greatjon),
#                        Masha-Heddle, Moreo-Tumitis, Mya-Stone, Mychel-Redfort,
#                        Robert-Arryn, Stevron-Frey, Tytos-Blackwood, Wendel-
#                        Manderly, Cayn, Janos-Slynt, Stannis-Baratheon, Chella,
#                        Clement-Piper, Karyl-Vance, Cohollo, Haggo, Qotho, Conn,
#                        Coratt, Doreah, Eroeh, Illyrio-Mopatis, Irri, Jhiqui, Mirri-
#                        Maz-Duur, Rhaegar-Targaryen, Viserys-Targaryen, Danwell-
#                        Frey, Hosteen-Frey, Jared-Frey, Dareon, Daryn-Hornwood,
#                        Torrhen-Karstark, Dolf, Donal-Noye, Jommo, Ogo, Rhaego,
#                        Dywen, Galbart-Glover, Gendry, High-Septon-(fat_one),
#                        Howland-Reed, Jacks, Joss, Marq-Piper, Porther, Raymun-
#                        Darry, Tobho-Mott, Tregar, Varly, Wyl-(guard), Wylla, Fogo,
#                        Roose-Bolton, Gared, Will-(prologue), Oswell-Whent, Todder,
#                        Gunthor-son-of-Gurn, Harys-Swyft, Heward, Hobb, Hugh, Jafer-
#                        Flowers, Kevan-Lannister, Matthar, Othor, Maege-Mormont,
#                        Jonos-Bracken, Jyck, Morrec, Kurleket, Lancel-Lannister,
#                        Leo-Lefford, Mace-Tyrell, Lyn-Corbray, Paxter-Redwyne,
#                        Maegor-I-Targaryen, Mord, Randyll-Tarly, Timett, Ulf-son-of-
#                        Umar],
#               'textfont': {'color': 'rgba(0,0,0,0)', 'size': 10},
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': '65b6053d-4cf4-4b7e-8fdd-678cfa9d4990',
#               'visible': True,
#               'x': [0.22497279778933718, 0.010251626732481109,
#                     0.037115510346755934, 0.044991135473526234,
#                     0.12742448449317192, -0.02871746503154129, -0.1660389712148836,
#                     -0.13435979770080062, -0.1656746123210016,
#                     -0.22659752461517788, -0.223157065680094, -0.10774132582906237,
#                     -0.12443486389470393, -0.17467570867653842,
#                     0.08491083176869271, -0.06601520955026732, 0.2990856928992369,
#                     0.028560286713746337, 0.0036048677372238006,
#                     0.1616998707866877, 0.1608139389089895, 0.15069620326913044,
#                     0.11343232239299353, 0.17989002597056203, 0.2218092418629976,
#                     -0.30591868260032035, -0.2189938502151478, -0.2428291048821547,
#                     -0.21866026486176832, -0.19705393675056707,
#                     0.031517490150687125, -0.15656006930816044,
#                     -0.25463187827609834, -0.11862803199269364,
#                     -0.11646974606144306, 0.5443819661251076, -0.09209666469664772,
#                     -0.1323861152240523, -0.09060749307545934, 0.06194025163852019,
#                     -0.022186201743025914, -0.3149465432067531,
#                     -0.0755085641596945, -0.11413549057479554,
#                     -0.046287056086820724, -0.14766884285656862,
#                     -0.09163438515407198, -0.1462622574933882,
#                     -0.13052013971891138, 0.0024492935087870346,
#                     -0.06370465548097369, -0.05074738356646757,
#                     0.003963020355184024, -0.048134864099364884,
#                     -0.05326118188860863, -0.19857399538804427,
#                     -0.057057969473292426, -0.10221669298002313,
#                     -0.05412668462874873, -0.029766098645670536,
#                     -0.01537939526896181, -0.15888516889231216,
#                     -0.023622714361501932, -0.028591419924496733,
#                     -0.1676207402606703, 0.02235291468424554, 0.02389194180820817,
#                     -0.15968913797957576, -0.08805631732446988,
#                     -0.42276427759102725, -0.03102323581745188,
#                     -0.3282096413556304, 0.13095309585043252, 0.07294869903960982,
#                     -0.04665127655024265, 0.3593529706999128, -0.47916860605197953,
#                     -0.0012380368393350154, -0.15710370473597254,
#                     -0.23913665653350702, -0.33857255949207893,
#                     -0.20562613501386748, -0.17326420759336403,
#                     -0.14750468137416475, -0.32545702723933445,
#                     -0.08700408067531994, -0.0106468936089344, 0.09712234377324344,
#                     0.19577124106598018, 0.1340611089084969, 0.12359448868303714,
#                     0.18336670261124258, 0.18762855181808544, 0.13487090684131448,
#                     0.10938868820537545, 0.19935865106779074, 0.20348610861290928,
#                     0.11330801445811606, 0.3398814065416274, 0.019376110765845708,
#                     0.33491895976602015, 0.43005033547133376, 0.3054872295046278,
#                     -0.17891586497063866, 0.3485155242018497, 0.44057160504569376,
#                     0.26365439873807583, 0.4421852157840424, 0.18945672889764617,
#                     0.23517886767169927, 0.42092733151261447, 0.26007799134487763,
#                     -0.1121886729370629, 0.09069044876566394, 0.040720318249053714,
#                     0.13973093777056655, 0.8117010618114285, 0.5368821793851772,
#                     0.24629594239151978, 0.21726183282470504, 0.19077616048481424,
#                     0.25489475338249495, 0.42590732670338605, 0.09412768350992229,
#                     0.11715293817266567, 0.12634131567576753, 0.11855241411821493,
#                     0.12136151630638026, 0.19347099638183396, 0.05033721076570676,
#                     0.10131094915199187, -0.19380566004563302, -0.2851318137426592,
#                     -0.33521363103141855, -0.3729140202607769, -0.2688654504382972,
#                     -0.20009954254700232, 0.31599696227290297, -0.3283952356910834,
#                     0.2610982246995917, 0.23685101176200013, 0.30961469329649466,
#                     -0.2841218052939753, -0.2039365687455249, -0.38169262618710575,
#                     -0.23374513182804255, 0.22558063616922255,
#                     -0.23199383687950093, 0.23956778163397352, 0.25688721168021583,
#                     -0.2949851579486325, 0.04353500827132854, -0.09162967472670386,
#                     0.07143157765872404, 0.2978360818376253, -0.2570983275390851,
#                     -0.3385235920228132, 0.32280021594986985, -0.2208842995371462,
#                     -0.28975491271610865, -0.3636057347538309, 0.603651316401021,
#                     -0.27120878788056957, 0.09901342126982747, 0.03688215153534709,
#                     -0.4009806829497142, -0.3754054344402451, -0.03787261011654385,
#                     -0.23347859582105096, 0.11494648298169821, -0.4740354788376653,
#                     -0.41846000523177146, -0.40565855350654595, 0.73296769310355,
#                     0.16384714030681152, 0.23667390169626007, 0.084662003428764,
#                     -0.1365913533630644, 0.07451585428173507, -0.3628549262274039,
#                     0.4569586768240586, -0.5765387587715262, -0.01985209311549138,
#                     0.07034472041081687, -0.3584368674764913, 0.21031458239679016,
#                     0.32433668365143337],
#               'y': [-0.08496436427478211, -0.04380961742058167,
#                     -0.04556504226486564, 0.34346518565637896, 0.44264659066810486,
#                     0.036267055185552, -0.32061719399610444, -0.2711176266171182,
#                     -0.3515056862058983, -0.4002085311648324, -0.5937025418802515,
#                     -0.252503304623172, -0.17729694503380924, -0.26228527482288605,
#                     0.12473561619199211, 0.13618269573462585, 0.23014075098947423,
#                     0.019328167884220482, 0.06583534728940707, 0.6005064938486256,
#                     0.5132799100665119, 0.5627851226084801, 0.44386355044543274,
#                     0.6645412717305139, 0.6614246042222187, -0.3843396473578988,
#                     -0.28336379292886205, -0.3361043215948849, -0.2430030947389447,
#                     -0.24376338894274635, -0.16127417515269063,
#                     0.13213256207037227, 0.11104111562652616, 0.016043508926059612,
#                     0.10571540890163818, 0.3705050133591164, -0.03435648026563328,
#                     -0.22621765165653507, -0.09795467628320692,
#                     -0.06618915395174273, -0.01750205930681156,
#                     0.03544766942456946, 0.0882885776627483, 0.05567572008766448,
#                     -0.014601758390320642, 0.0788485666605368,
#                     -0.004053042826987958, 0.006970186251841997,
#                     -0.028464498408835425, 0.011523455013212168,
#                     -0.12730109514013377, -0.08496490340979346,
#                     -0.09203232574546034, 0.032972193429283654,
#                     0.00081962783918899, 0.0201330310551726, -0.10241609255164577,
#                     0.12761432142005635, -0.22210377487232855,
#                     -0.39950496978353084, 0.28442934444591567, 0.2839262297863815,
#                     0.05676646183254871, 0.07612655697441971, 0.056816218390136744,
#                     0.05085117760306701, 0.07424730451617607, -0.4152098219140684,
#                     -0.11784774625240702, -0.47601159352442646,
#                     -0.10105305642713791, -0.6144319015896641, 0.17039425847655115,
#                     0.034753168571194, 0.12442501654906041, 0.3230045578696649,
#                     -0.13997028994030153, -0.1678612430945333,
#                     -0.14476535453066053, -0.04611141244282632,
#                     -0.15602532732361452, -0.14749361591025287,
#                     -0.17411123571009152, -0.08086804850954817,
#                     0.07541043068018125, -0.3371958802516062, 0.15352205106340697,
#                     -0.20358152371829957, -0.2994625371198724,
#                     -0.18371248606942062, -0.30634815874690446,
#                     -0.3746621423223285, -0.20640621118625707,
#                     -0.21967640922921824, -0.06118531894569941,
#                     -0.038527514911401585, 0.001171497239993225,
#                     -0.08228838589389197, -0.12457214831482036,
#                     0.11311563170645042, -0.2663976279704909, -0.00684127496637056,
#                     -0.20054294164927028, -0.10020259579276997,
#                     -0.059182703212987055, -0.07393001094514226,
#                     -0.1305009878746726, -0.13056935483260923,
#                     -0.16921984605255166, 0.09268415825389037,
#                     -0.16605070599199862, -0.04939670965091072,
#                     0.21239984013450902, 0.08036713940899422, 0.03787620726927046,
#                     -0.44502845647109696, 0.0429790738827993, 0.02277104293546673,
#                     0.5949285473098034, 0.5769598159430281, 0.549854725979277,
#                     -0.4329025992312093, -0.6383101566967293, 0.5583376061540684,
#                     0.7186884483331629, 0.3856023877157474, 0.517464941498897,
#                     0.5473969147316472, 0.5110471029680168, 0.19907184741777034,
#                     0.3875788216699216, 0.6186573478626463, 0.909399024917342,
#                     0.887983584617064, -0.28139221192839486, 0.31497845469404867,
#                     0.18166686472542337, -0.5658817432379483, -0.3178607454595056,
#                     0.8299966700546267, 0.748281088622307, 0.7375108622498646,
#                     -0.46457911553639597, -0.04421651183456801,
#                     0.21309686890284602, 0.15384839726899394, 0.2756448527590119,
#                     0.2902236543996118, 0.1484149538256008, 0.03791085183035738,
#                     0.2355759063004008, 0.232779520069315, 0.2716874400274791,
#                     -0.2379201087597027, 0.0655105630780051, 0.057540878323252435,
#                     0.28390399717140546, 1.0, -0.10033966795492102,
#                     -0.5960392021881452, -0.7057894701200815, 0.3827575880562137,
#                     -0.2650133996743546, -0.3852831788473103, -0.41647305879552193,
#                     0.08911477176752691, -0.35426879218879465, 0.3738405200186497,
#                     -0.7549739681322872, -0.14338730497725938,
#                     -0.34904546298035055, -0.2648342780870994,
#                     -0.10225376230628262, -0.2655801009306158,
#                     -0.39481419372825133, -0.3713616959327967, -0.454435527701186,
#                     0.40979246444448686, -0.5053713997333977, 0.47153885311237625,
#                     -0.24580511010023035, 0.692047030769484, -0.30532628399061523,
#                     -0.292408832156223, -0.4895617243181842, -0.48531995723806637,
#                     -0.6463256817594365]}],
#     'layout': {'height': 800,
#                'hovermode': 'closest',
#                'margin': {'b': 20, 'l': 5, 'r': 5, 't': 40},
#                'paper_bgcolor': 'white',
#                'plot_bgcolor': 'white',
#                'showlegend': False,
#                'template': '...',
#                'title': {'text': 'Game of Thrones Character Network with Zoom-Dependent Labels'},
#                'width': 1200,
#                'xaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False},
#                'yaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False}}
# })
